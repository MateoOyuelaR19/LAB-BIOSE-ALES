# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %% [markdown]
# a)

# %%
a= np.array([3.1,1,-0.5,-3.2,6])
b= np.array([1,3,2.2,5.1,1])

# %% [markdown]
# b)

# %%
dot1= a@b
dot2= a.dot(b)

# %% [markdown]
# c)

# %%
m1=np.multiply(a,b)
m2=a*b

# %% [markdown]
# d)

# %%
A=np.array([(2,-1,-3),(4, 1.5,-2.5),(7.3,-0.9,0.2)])
print(A)

# %% [markdown]
# e)

# %%
AT=np.transpose(A)

# %% [markdown]
# f)

# %%
#ones: crea un arreglo compuesto de unos(1)
ones1=np.ones((2,3,4))
#round: Aproxima los elementos de un arreglo
a_rounded=np.round(a)
a_rounded_2decimals=np.round(a,2)
#ceil: devuelve el entero mayor más cercano de cada elemento de un arreglo
ceil_a=np.ceil(a)
#floor: devuelve el entero menor más cernano de cada elemento del arreglo
floor_a=np.floor(a)

# %% [markdown]
# g)

# %%
A_value=A[0,2]
print(A_value)
# Out:
# -3.0

# %% [markdown]
# h)

# %%
A_2nd_row=A[1,:]
print(A_2nd_row)
# Out:
# [ 4.   1.5 -2.5]

# %% [markdown]
# i)

# %%
#shape para conocer las dimensiones del arreglo
A_shape=np.shape(A)
print(A_shape)

#ndim para conocer la cantidad de dimensiones del arreglo
A_ndim=np.ndim(A)
print(A_ndim)
# Out:
# (3, 3)
# 2

# %% [markdown]
# j)

# %%
n=np.linspace(0,100,101)
yn=np.sin(np.pi*0.12*n)

# %% [markdown]
# k)

# %%
y2n=np.cos(2*np.pi*0.03*n)

# %% [markdown]
# l)

# %%
sn=yn+y2n

tn=yn*y2n

# %% [markdown]
# m)

# %%
plt.plot(n,yn,label='y[n]')
plt.plot(n,y2n,label='y2[n]')
plt.xlabel('n')
plt.ylabel('y[n],y2[n]')
plt.legend()

# %% [markdown]
# n)

# %%
plt.plot(n,sn,label='s[n]')
plt.plot(n,tn,label='t[n]')
plt.xlabel('n')
plt.ylabel('s[n],t[n]')
plt.legend()
